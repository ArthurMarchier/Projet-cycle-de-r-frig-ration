# %% [markdown]
# ### Réponse aux questions - Optimisation d'un cycle de réfrigération au CO2

# %% [markdown]
# ### Q1.1 : En utilisant une méthode itérative, déterminez la température de condensation ($T_{cond}$) (et la pression de saturation associée $P_{3s}$) permettant de respecter le pincement et l'échauffement de l'air. Pour commencer, écrire un bilan de puissance qui inclurait $T_{cond}$.

# %% [markdown]
# $c_{p, air} (T_{Ap} - T_{A1}) = \Delta h_{f4 \to f3 sl} + \Delta h_{f3 sl \to f3 sv}$
#
# $c_{p, air} (T_{Ap} - T_{A1}) = l_{vaporisation, CO_{2}}(T_{cond}) - c_{p, CO_{2}, liq} (T_{f4s} - T_{cond})$
#
# Or on a que $T_{Ap} = T_{cond} - 5$ et $T_{A1} = T_{amb}$
#
# On obtient ainsi $T_{cond} = T_{amb} + 5 + \frac{l_{vaporisation, CO_{2}}(T_{cond}) - c_{p, CO_{2}, liq} (T_{f4s} - T_{cond})}{c_{p, air}}$
#
# On va poser $T_0 = 25°C$, soit la température si $Ap=A_2$, et on va itérer en posant à chaque itération :
#
# $T_{k+1} = T_{amb} + 5 + \frac{l_{vaporisation, CO_{2}}(T_{k}) - c_{p, CO_{2}, liq}(T_{k}) (T_{f4s} - T_{cond})}{c_{p, air}(T_{k})}$
#
# Cela va converger vers $T_{cond}$.
#
# On obtient grâce à Coolprop : $T_{cond} = 295 K = 22°C$ et $P_{3s} = 5958210 Pa \approx 59,6 bar$

# %% [markdown]
# ### Q1.2 : Calculez le COP (Coefficient de Performance) du cycle pour ces conditions et tracez le diagramme T-s en y affichant le profil de température de l’air.

# %% [markdown]
# On a le COP qui est : $\eta = \frac{q_f}{w}$
#
# Or le premier principe de la thermodynamique sur des cycles donne : $w + q_c + q_f = 0$ don $q_f = - w - q_c$ d'où $\eta = -1 - \frac{q_c}{w}$
#
# On a dans le cas isentropique que $w^{is} = \Delta h_{1f \to 2f} = \frac{1}{\rho_{CO_{2}, gaz}}(P_{2f} - P_{1f})$ car $dh = Tds + vdP$
#
# Donc dans le cas réel : $w = \frac{w^{is}}{\eta_{is}}$
#
# Et $q_c = - \Delta h_{A1 \to A2} = -c_{p,air}(T_{A2} - T_{A1})$
#
# Il reste à déterminer $P_{1f}$ et $P_{2f}$. Pour cela on utilise l'équation d'état des gaz parfaits :
#
# $\frac{P_{1f}}{T_{1f}} = \frac{nR}{V} = \frac{P_{5s}}{T_{5f}}$ donc $P_{1f} = P_{5s} \frac{T_{1f}}{T_{5f}}$ où $P_{5s} = 28.0 bar$ est obtenu via Coolprop.
#
# De même : $P_{2f} = P_{3s} \frac{T_{2f}}{T_{cond}}$ et on a que $c_{p,CO_{2},gaz}(T_{2f} - T_{cond}) = c_{p,air}(T_{A2} - T_{Ap})$ donc $T_{2f} = T_{cond} + \frac{c_{p,air}}{c_{p,CO_{2},gaz}}(T_{A2} - T_{Ap})$
#
# On obtient $P_{f1}$ et $P_{f2}$ à environ 30 bar en ordre de grandeur. A ces condition de témpérature et pression, $\rho_{CO_{2}, gaz} \approx 950kg/m^3$
#
# Après calculs, on obtient que : $\eta \approx 0,119 $

# %% [markdown]
# ### Q2.1 : Proposez une hypothèse pour définir la température de sortie du refroidisseur. Analysez l'effet de la pression de refoulement ($𝑃_3$) sur le COP. Commencez l’analyse avec une pression de 120 bar. Tracez le diagramme T-s pour le cas de pression optimale en prenant soin de bien tracer le profil de refroidissement du CO2.

# %% [markdown]
# Pour définir la température de sortie du refroidisseur, il faut que $T_{cond} > T_{amb} + 5K = 35K$ étant donné qu'on a toujours un pincement de $5K$. Or à cette température, on a un changement d'état par passage dans l'état supercritique. On a donc pas d'étape de condensation à température constante et on ne peut plus vraiment parler de $T_{cond}$.
#
# Cette fois-ci, l'effet du refroidisseur sera représenté sous la forme d'une droite de 2f à 3f sur le diagramme T-s car on a une absence de phase diphasée, et le pincement sera obtenue en sortie du refroidisseur. on fait donc l'hypothèse que $T_3 = 35K$.

# %% [markdown]
# On a : $\eta = -1 - \frac{q_c}{w}$
#
# On a toujours $q_c = -c_{p,air}(T_{A2} - T_{A1})$
#
# $w = h_2 - h_1$
#
# On a $h_3 - h_2 = -c_{p,air}(T_{A2} - T_{A1})$ donc $h_2 = h_3 + c_{p,air}(T_{A2} - T_{A1})$
